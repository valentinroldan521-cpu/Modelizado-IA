# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinroldan521-cpu/Modelizado-IA/blob/main/Valentin_Roldan_Practica_Unidad_3_Preceptron_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller Práctico: Clasificación de Riesgo Crediticio con Perceptrón
# ## Contexto del Problema
# Una entidad financiera desea automatizar la aprobación de créditos pre-aprobados.
#
# Se cuenta con dos variables de entrada:
#
# * Puntaje Crediticio (Normalizado de 0 a 1).
#
# * Ratio de Ahorro (Dinero ahorrado vs ingresos anuales).
#
# El objetivo es entrenar un Perceptrón Simple en Keras para que aprenda la frontera de decisión que separa a los clientes de "Bajo Riesgo" (Clase 1) de los de "Alto Riesgo" (Clase 0).

# %% [markdown]
# ## Paso 1: Preparación del Entorno
# Cargamos las librerías necesarias y generamos un dataset sintético que represente este escenario.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons, make_blobs

# Generamos datos: 300 clientes con 2 características
X, y = make_blobs(n_samples=300, centers=2, n_features=2, cluster_std=1.5, random_state=1)

# Visualización inicial
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolors='k')
plt.xlabel("Puntaje Crediticio")
plt.ylabel("Ratio de Ahorro")
plt.title("Distribución de Clientes")
plt.show()

# %% [markdown]
# ## Paso 2: Definición de la Arquitectura (Misión del Alumno)
# Debes definir un modelo secuencial que represente un Perceptrón Simple. Recuerda que para una clasificación binaria, la salida debe pasar por una función que comprima el valor entre 0 y 1.
#
# **Guía Técnica:**
#
# * Usa una capa Dense.
#
# * Como es un Perceptrón de una sola capa, units debe ser igual a 1.
#
# * El input_shape debe coincidir con la cantidad de variables de entrada (2).

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
#Definimos el modelo secuencial.
model = Sequential([
    #Tiene capa unica que es el perceptron
    # Define la capa Dense con 1 neurona y activación 'sigmoid'
#Tiene una sola capa de salida
# input_shape=(2,): Puntaje crediticio y ahorro
    Input(shape=(2,)), Dense(units=1, activation='sigmoid')

    ])
model.summary()
# ------------------------------
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Paso 3: Compilación del Sistema
# Para que el modelo aprenda, debemos definir el Optimizador (que gestiona la Tasa de Aprendizaje) y la Función de Pérdida (que mide el error).
#
# **Ayuda Sugerida:**
#
# * Para clasificación binaria, la pérdida estándar es binary_crossentropy.
#
# * Experimenta con diferentes valores en learning_rate (prueba con 0.01, 0.1 y 0.5).

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
# Usa model.compile(...)
# Define el optimizer usando tf.keras.optimizers.SGD y la loss adecuada.
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), #Se puede testear/probar con un rango minimo desde 0.01 hasta un maximo de 0.5
    loss='binary_crossentropy',
    metrics=['accuracy']
)


#Por ultimo ponemos print y dentro de los () agregamos que la "Configuracion de entramiento ya esta finalizado"
print("Configuracion de entrenamiento ya esta finalizado")
# ------------------------------
# Out:
# Configuracion de entrenamiento ya esta finalizado

# %% [markdown]
# ## Paso 4: Entrenamiento y Regularización
# Es momento de ajustar los pesos. Vamos a entrenar el modelo, pero esta vez, presta atención a cómo el número de épocas afecta el resultado.
#
# **Instrucciones:**
#
# * Ejecuta el método .fit().
#
# * Prueba configurar el entrenamiento con 50 épocas.

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
# history = model.fit(..., epochs=..., verbose=1)

#Definimos X_Train y despues vamos aplicando los ejemplos de la actividad en base al puntaje crediticio y ratio de ahorro

x_train= np.array([
    [0.7, 0.9], [0.3, 0.5], [0.9, 0.8], [0.4, 0.5], [0.25, 0.3], [0.45, 0.4],
    [0.85, 0.9], [0.8, 0.9], [0.1, 0.15], [0.01, 0.55]
])

#Ahora definimos los siguientes parametros:
#Estos parametros tendran las siguientes etiquetas:
# 1 = Bajo Riesgo (APROBADO), 0 = Alto Riesgo (DENEGADO)
#Definimos Y_Train
y_train= np.array([1, 1, 1, 0, 0, 0, 1, 1, 0, 0])

history = model.fit(
    x_train, y_train, epochs=50, verbose=1
    )


# ------------------------------
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5000 - loss: 0.8621
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5000 - loss: 0.8611
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8600
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.8589
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8579
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8568
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8558
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.8548
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8537
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8527
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 0.8517
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8507
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.8497
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8487
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8477
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8467
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8458
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8448
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8438
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8429
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8419
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8410
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8400
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8391
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.8381
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8372
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8363
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.8354
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.8345
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8336
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8327
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8318
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8309
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8300
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8291
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8282
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8274
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5000 - loss: 0.8265
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8257
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8248
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8240
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8231
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.8223
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8214
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8206
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.8198
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.8190
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8182
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.8174
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.8166

# %% [markdown]
# ## Paso 5: Evaluación de Resultados
# Una vez entrenado, utilizaremos el siguiente bloque para visualizar la Frontera de Decisión que tu modelo ha construido.

# %%
#Definimos plot_frontier y a su lado entre () ponemos los ejes (x,y).

def plot_frontier(X, y, model):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

#Seguimos poniendo los x,y, pero aca tendran un valor maximo(max) minimo(min)

    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.4, cmap='bwr')
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap='bwr')
    plt.show()

plot_frontier(X, y, model)
# Out:
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Desafíos Extra
# **Impacto del Sesgo:** Si imprimes los pesos del modelo con model.get_weights(), ¿cuál es el valor del Bias?
#
# ¿Qué pasaría si fuera cero?
#
# **Regularización:** Regresa al Paso 2 e intenta agregar kernel_regularizer='l2' dentro de la capa Dense.
#
# ¿Notas algún cambio en la suavidad de la frontera o en el valor de los pesos?
#
# **No Linealidad:** Cambia el generador de datos por make_moons(n_samples=300, noise=0.1).
#
# ¿Es capaz el Perceptrón de una sola capa de separar estos datos? Justifica basándote en la teoría de Separabilidad Lineal.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import regularizers

# 1. Generamos un set de datos sintético con 2 características de entrada (X_train)
X_train, y_train = make_blobs(n_samples=100, centers=2, n_features=2, random_state=42, cluster_std=1.5)

# 2. Definimos el modelo secuencial (igual al tuyo)
model = Sequential([
    Input(shape=(2,)),
    Dense(units=1,
          activation='sigmoid',
          kernel_regularizer=regularizers.l2(0.1))
])

# 3. Compilamos el modelo
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 4. Entrenamos por unas cuantas épocas para que la línea se ajuste bien a los datos
model.fit(X_train, y_train, epochs=100, verbose=0)

# 5. Extraemos los pesos y el bias finales
weights, bias = model.get_weights()

# 6. Creamos el Gráfico de Dispersión (Scatter plot)
# Graficamos los puntos de la Clase 0 (Rojo) y Clase 1 (Azul)
plt.scatter(X_train[y_train == 0, 0], X_train[y_train == 0, 1], color='red', label='Clase 0', edgecolor='k')
plt.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], color='blue', label='Clase 1', edgecolor='k')

# 7. Calculamos la línea de la Frontera de Decisión usando los pesos y el bias
# Ecuación matemática: w1*x1 + w2*x2 + bias = 0  ->  Despejamos x2: x2 = -(w1*x1 + bias) / w2
x1_min, x1_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
x1_vals = np.linspace(x1_min, x1_max, 100)
x2_vals = -(weights[0][0] * x1_vals + bias[0]) / weights[1][0]

# Dibujamos la línea verde de la frontera
plt.plot(x1_vals, x2_vals, color='green', linestyle='--', linewidth=2, label='Frontera de Decisión')

# Configuraciones del gráfico
plt.xlabel('Característica 1 (Entrada 1)')
plt.ylabel('Característica 2 (Entrada 2)')
plt.title('Gráfico de Dispersión con Frontera de Decisión del Modelo')
plt.legend(loc='best')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()

# Guardamos el gráfico
plt.savefig('grafico_dispersion_neurona.png')
